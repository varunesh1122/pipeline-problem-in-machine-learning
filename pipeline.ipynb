# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
steps=[("standard_scaler",StandardScaler()),
       ("classifier",LogisticRegression())]

# %%
steps
# Out:
# [('standard_scaler', StandardScaler()), ('classifier', LogisticRegression())]

# %%
pipe=Pipeline(steps)
pipe
# Out:
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('classifier', LogisticRegression())])

# %%
from sklearn import set_config

# %%
set_config(display="diagram")

# %%
pipe
# Out:
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('classifier', LogisticRegression())])

# %%
from sklearn.datasets import make_classification
x,y=make_classification(n_samples=1000)

# %%
x.shape
# Out:
# (1000, 20)

# %%
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split
x_train,xtest,y_train,y_test=train_test_split(
    x,y,test_size=0.33, random_state=42)

# %%
x_train
# Out:
# array([[-0.07410003, -1.17021503, -0.21597958, ...,  1.40843327,
#         -0.8028692 ,  0.67651028],
#        [-1.16992001,  0.66738881, -2.04312717, ...,  0.05816887,
#          1.20514244, -0.36989041],
#        [ 0.46377689,  0.98574464, -0.71198187, ..., -0.9588664 ,
#         -2.56703939,  0.18209893],
#        ...,
#        [ 0.95905676, -1.58292786,  1.03172179, ...,  0.81732514,
#         -0.73906688, -0.39737088],
#        [-0.09131391,  0.21094875, -1.020527  , ..., -2.17532229,
#         -0.32473415, -1.13112231],
#        [ 0.31805926, -1.21443089,  0.75201728, ..., -1.16570883,
#          0.20303523,  0.76962299]])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('standard_scaler', StandardScaler()),
#                 ('classifier', LogisticRegression())])

# %%
y_pred=pipe.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 y_pred=pipe.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.decomposition import PCA
from sklearn.svm import SVC

# %%
steps=[("scaling",StandardScaler()),
      ("PCA",PCA(n_components=3)),
      ("SVC",SVC())]

# %%
 pipe2=Pipeline(steps)

# %%
pipe2.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('scaling', StandardScaler()), ('PCA', PCA(n_components=3)),
#                 ('SVC', SVC())])

# %%
Pipeline(steps=[('scaling', StandardScaler()), ('PCA', PCA(n_components=3)),
                ('SVC', SVC())])
# Out:
# Pipeline(steps=[('scaling', StandardScaler()), ('PCA', PCA(n_components=3)),
#                 ('SVC', SVC())])

# %%
pipe2.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 pipe2.predict(x_test)
#
# NameError: name 'x_test' is not defined

# %%
 from sklearn.impute import SimpleImputer
import numpy as np

# %%
numeric_processor=Pipeline(    
steps=[("imputation_mean",SimpleImputer(missing_values=np.nan,strategy
 ="mean")),
          ("scaler",StandardScaler())]
 )
numeric_processor
Pipeline(steps=[('imputation_mean', SimpleImputer()),
                ('scaler', StandardScaler())])
# Out:
# Pipeline(steps=[('imputation_mean', SimpleImputer()),
#                 ('scaler', StandardScaler())])

# %%
from sklearn.preprocessing import OneHotEncoder
categorical_processor=Pipeline(steps=[("imputation_consatnt",SimpleImputer(fill_value="missing",
                                    strategy="constant")),
          ("onehot",OneHotEncoder(handle_unknown="ignore"))]
 )
categorical_processor
Pipeline(steps=[('imputation_consatnt',
                 SimpleImputer(fill_value='missing', 
strategy='constant')),
                ('onehot', OneHotEncoder(handle_unknown='ignore'))])
# Out:
# Pipeline(steps=[('imputation_consatnt',
#                  SimpleImputer(fill_value='missing', strategy='constant')),
#                 ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer
preprocessor=ColumnTransformer([("categorical",categorical_processor,["gender","City"]),
                                ("numerical",numeric_processor,["age","height"])]
                              ) 
preprocessor
ColumnTransformer(transformers=[('categorical',                                 
Pipeline(steps=[('imputation_consatnt',                                                  
SimpleImputer(fill_value='missing',                                                               
strategy='constant')),
('onehot',                                                
OneHotEncoder(handle_unknown='ignore'))]),
                                 ['gender', 'City']),
                                ('numerical',
                                 Pipeline(steps=[('imputation_mean',
                                                  SimpleImputer()),
                                                 ('scaler', 
StandardScaler())]), ['age', 'height'])])
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('imputation_consatnt',
#                                                   SimpleImputer(fill_value='missing',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['gender', 'City']),
#                                 ('numerical',
#                                  Pipeline(steps=[('imputation_mean',
#                                                   SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['age', 'height'])])

# %%
from sklearn.pipeline import make_pipeline
pipe=make_pipeline(preprocessor,LogisticRegression())
pipe
Pipeline(steps=[('columntransformer',
                 ColumnTransformer(transformers=[('categorical',
                                                  
Pipeline(steps=[('imputation_consatnt',
                                                                   
SimpleImputer(fill_value='missing',
                                                                       
strategy='constant')),
                                                                  
('onehot',
                                                                   
OneHotEncoder(handle_unknown='ignore'))]),
                                                  ['gender', 'City']),
                                                 ('numerical',
                                                  
Pipeline(steps=[('imputation_mean',
                                                                   
SimpleImputer()),
                                                                  
('scaler',
                                                                   
StandardScaler())]),
                                                  ['age', 
'height'])])),
                ('logisticregression', LogisticRegression())])
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('imputation_consatnt',
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['gender', 'City']),
#                                                  ('numerical',
#                                                   Pipeline(steps=[('imputation_mean',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'height'])])),
#                 ('logisticregression', LogisticRegression())])
